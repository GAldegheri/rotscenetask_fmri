# %%
import nibabel as nb
import numpy as np
import os
from glob import glob
from nilearn.plotting import plot_anat, plot_roi

from rois.roi_utils import create_functional_roi

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/predatt/giaald/.conda/envs/giacomo37/lib/python3.8/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "
# 230621-16:46:00,571 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.6.0-dev+g804adc0

# %%
plot_roi('sub-001_ba-17-18_R_contr-objscrvsbas_top-500.nii')

# %%
nvoxels = 200
create_functional_roi('sub-005', 'ba-17-18', nvoxels=nvoxels,
                      split_lr=True, out_dir='.')
# Out:
# > /project/3018040.05/rotscenetask_fmri/analysis/rois/roi_utils.py(74)create_functional_roi()
#      72     pdb.set_trace()
#      73
# ---> 74     task = roi_dict[roiname]['task']
#      75     model = roi_dict[roiname]['model']
#      76     contrast = roi_dict[roiname]['contrast']
# ipdb>  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /scratch/giaald/49327618.dccn-l029.dccn.nl/ipykernel_18117/3922996496.py in <module>
#       1 nvoxels = 200
# ----> 2 create_functional_roi('sub-005', 'ba-17-18', nvoxels=nvoxels,
#       3                       split_lr=True, out_dir='.')
#
# /project/3018040.05/rotscenetask_fmri/analysis/rois/roi_utils.py in create_functional_roi(sub, roiname, nvoxels, tthresh, split_lr, out_dir)
#      72     pdb.set_trace()
#      73
# ---> 74     task = roi_dict[roiname]['task']
#      75     model = roi_dict[roiname]['model']
#      76     contrast = roi_dict[roiname]['contrast']
#
# /project/3018040.05/rotscenetask_fmri/analysis/rois/roi_utils.py in create_functional_roi(sub, roiname, nvoxels, tthresh, split_lr, out_dir)
#      72     pdb.set_trace()
#      73
# ---> 74     task = roi_dict[roiname]['task']
#      75     model = roi_dict[roiname]['model']
#      76     contrast = roi_dict[roiname]['contrast']
#
# ~/.conda/envs/giacomo37/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/.conda/envs/giacomo37/lib/python3.8/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
glob(os.path.join(roidir, '*.nii'))

# %%
vol_data = nb.load('/project/3018040.05/roi_masks/LO.nii').get_fdata()

# %%
vol_data.shape

# %%
vol = nb.load('/project/3018040.05/roi_masks/LO.nii')
-np.sort(-vol.get_fdata().flatten())

# %%
f'model_{5}'

# %%
from collections.abc import Iterable

a = np.array([1, 2, 3])
b = ['1', '2', '3']
isinstance(a, Iterable)

# %%
oo = np.random.rand(3,3,3)

# %%
oo.max()

# %%
for x, y in zip(a, b):
    print(x, y)

# %%
xx = (2, 3)
yy = ['a', 'b']

# %%
for i, j in zip(xx, yy):
    print(i, j)

# %%
b = [1, 2, 3]
isinstance(b, Iterable)
